# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df =pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
df_class0 = df.loc[df["target"]==0]

# %%
df_class0
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %%
df_class1 = df.loc[df['target']==1]

# %%
df_class2 = df.loc[df['target']==2]

# %%
plt.plot(df_class0['sepal length (cm)'],np.zeros_like(df_class0['sepal length (cm)']),'o')
plt.plot(df_class1['sepal length (cm)'],np.zeros_like(df_class1['sepal length (cm)']),'o')
plt.plot(df_class2['sepal length (cm)'],np.zeros_like(df_class2['sepal length (cm)']),'o')
plt.xlabel('sepal length')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df,hue = 'target',size = 5).map(plt.scatter,'sepal length (cm)','sepal width (cm)').add_legend();
# Out:
# C:\anaconda\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Multi variate Analysis

# %%
sns.pairplot(df,hue = 'target',size = 5);
# Out:
# C:\anaconda\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
